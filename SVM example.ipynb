# %%
#svm on iris dataset
from sklearn import datasets
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

iris=datasets.load_iris() #creating data object
#splitting data into features and label
X=iris.data
y=iris.target

classes=['Iris Setosa','Iris Versicolour','Iris Verginica']

print(X.shape)
print(y.shape)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=svm.SVC()              #SVC support vector classifier
model.fit(X_train,y_train)
print(model)

predictions=model.predict(X_test)
accuracy=accuracy_score(predictions,y_test)

print('prediction: ',predictions)
print('actual:',y_test)
print('accuracy:',accuracy)

for i in range(len(predictions)):
    print(classes[predictions[i]])
# Out:
# (150, 4)
# (150,)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# prediction:  [0 0 0 2 2 1 1 1 0 0 2 1 2 1 2 2 1 1 0 1 2 2 1 0 2 2 2 1 0 2]
# actual: [0 0 0 2 1 1 1 1 0 0 2 1 2 1 2 1 1 1 0 1 2 2 1 0 2 2 2 1 0 2]
# accuracy: 0.9333333333333333
# Iris Setosa
# Iris Setosa
# Iris Setosa
# Iris Verginica
# Iris Verginica
# Iris Versicolour
# Iris Versicolour
# Iris Versicolour
# Iris Setosa
# Iris Setosa
# Iris Verginica
# Iris Versicolour
# Iris Verginica
# Iris Versicolour
# Iris Verginica
# Iris Verginica
# Iris Versicolour
# Iris Versicolour
# Iris Setosa
# Iris Versicolour
# Iris Verginica
# Iris Verginica
# Iris Versicolour
# Iris Setosa
# Iris Verginica
# Iris Verginica
# Iris Verginica
# Iris Versicolour
# Iris Setosa
# Iris Verginica
